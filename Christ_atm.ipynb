# %% [markdown]
# <a href="https://colab.research.google.com/github/AathiganapathiK/Atm-Cashout-Prediction/blob/main/Christ_atm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('christ college atm.csv')

# %%
df.columns = df.columns.str.strip()  # Clean column names

# %%
df.head()
# Out:
#              ATM Name Transaction Date  No Of Withdrawals  \
# 0  Christ College ATM       01-01-2011                 74
# 1  Christ College ATM       02-01-2011                 80
# 2  Christ College ATM       03-01-2011                108
# 3  Christ College ATM       04-01-2011                143
# 4  Christ College ATM       05-01-2011                 95
#
#    No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                          25                            49
# 1                          24                            56
# 2                          46                            62
# 3                          41                           102
# 4                          41                            54
#
#    Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 0                  287700                     148200
# 1                  300000                      95600
# 2                  522800                     210900
# 3                  737400                     238000
# 4                  387300                     213600
#
#    Amount withdrawn Other Card    Weekday Festival Religion Working Day  \
# 0                       139500   Saturday                 C           H
# 1                       204400     Sunday                NH           H
# 2                       311900     Monday                NH           W
# 3                       499400    Tuesday                NH           W
# 4                       173700  Wednesday                NH           W
#
#   Holiday Sequence
# 0              WHH
# 1              HHW
# 2              WWW
# 3              WWW
# 4              WWW

# %%
df['Weekday'].unique()
# Out:
# array(['Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday',
#        'Friday', 'SUNDAY', 'SATURDAY', 'MONDAY', 'TUESDAY', 'THURSDAY',
#        'FRIDAY', 'WEDNESDAY'], dtype=object)

# %%
# Convert 'Transaction Date' to datetime
df["Transaction Date"] = pd.to_datetime(df["Transaction Date"], format="%d-%m-%Y")
df.head()
# Out:
#              ATM Name Transaction Date  No Of Withdrawals  \
# 0  Christ College ATM       2011-01-01                 74
# 1  Christ College ATM       2011-01-02                 80
# 2  Christ College ATM       2011-01-03                108
# 3  Christ College ATM       2011-01-04                143
# 4  Christ College ATM       2011-01-05                 95
#
#    No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                          25                            49
# 1                          24                            56
# 2                          46                            62
# 3                          41                           102
# 4                          41                            54
#
#    Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 0                  287700                     148200
# 1                  300000                      95600
# 2                  522800                     210900
# 3                  737400                     238000
# 4                  387300                     213600
#
#    Amount withdrawn Other Card    Weekday Festival Religion Working Day  \
# 0                       139500   Saturday                 C           H
# 1                       204400     Sunday                NH           H
# 2                       311900     Monday                NH           W
# 3                       499400    Tuesday                NH           W
# 4                       173700  Wednesday                NH           W
#
#   Holiday Sequence
# 0              WHH
# 1              HHW
# 2              WWW
# 3              WWW
# 4              WWW

# %%
# Add `is_festival` column
df["is_festival"] = df["Festival Religion"].apply(lambda x: 1 if str(x).strip() != "NH" else 0)

# %%
df.tail()
# Out:
#                 ATM Name Transaction Date  No Of Withdrawals  \
# 2350  Christ College ATM       2017-09-25                174
# 2351  Christ College ATM       2017-09-26                110
# 2352  Christ College ATM       2017-09-27                149
# 2353  Christ College ATM       2017-09-28                187
# 2354  Christ College ATM       2017-09-29                143
#
#       No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 2350                          52                           122
# 2351                          34                            76
# 2352                          46                           103
# 2353                          76                           111
# 2354                          61                            82
#
#       Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 2350                  755300                     310800
# 2351                  325300                      76000
# 2352                  722600                     318100
# 2353                 1120300                     549100
# 2354                  700400                     364200
#
#       Amount withdrawn Other Card    Weekday Festival Religion Working Day  \
# 2350                       444500     MONDAY                NH           W
# 2351                       249300    TUESDAY                NH           W
# 2352                       404500  WEDNESDAY                NH           W
# 2353                       571200   THURSDAY                NH           W
# 2354                       336200     FRIDAY                 H           H
#
#      Holiday Sequence  is_festival
# 2350              HWW            0
# 2351              WWW            0
# 2352              WWW            0
# 2353              WWH            0
# 2354              WHH            1

# %%
# Encode weekday as numerical
weekday_map = {
    "Monday": 0, "Tuesday": 1, "Wednesday": 2, "Thursday": 3,
    "Friday": 4, "Saturday": 5, "Sunday": 6, "MONDAY":0, "TUESDAY":1, "WEDNESDAY":2, "THURSDAY":3,
    "FRIDAY":4, "SATURDAY":5, "SUNDAY":6
}
df["Day_of_Week"] = df["Weekday"].map(weekday_map)

# %%
df.head()
# Out:
#              ATM Name Transaction Date  No Of Withdrawals  \
# 0  Christ College ATM       2011-01-01                 74
# 1  Christ College ATM       2011-01-02                 80
# 2  Christ College ATM       2011-01-03                108
# 3  Christ College ATM       2011-01-04                143
# 4  Christ College ATM       2011-01-05                 95
#
#    No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                          25                            49
# 1                          24                            56
# 2                          46                            62
# 3                          41                           102
# 4                          41                            54
#
#    Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 0                  287700                     148200
# 1                  300000                      95600
# 2                  522800                     210900
# 3                  737400                     238000
# 4                  387300                     213600
#
#    Amount withdrawn Other Card    Weekday Festival Religion Working Day  \
# 0                       139500   Saturday                 C           H
# 1                       204400     Sunday                NH           H
# 2                       311900     Monday                NH           W
# 3                       499400    Tuesday                NH           W
# 4                       173700  Wednesday                NH           W
#
#   Holiday Sequence  is_festival  Day_of_Week
# 0              WHH            1            5
# 1              HHW            0            6
# 2              WWW            0            0
# 3              WWW            0            1
# 4              WWW            0            2

# %%
# Sort by date
df.sort_values("Transaction Date", inplace=True)
df.head()
# Out:
#              ATM Name Transaction Date  No Of Withdrawals  \
# 0  Christ College ATM       2011-01-01                 74
# 1  Christ College ATM       2011-01-02                 80
# 2  Christ College ATM       2011-01-03                108
# 3  Christ College ATM       2011-01-04                143
# 4  Christ College ATM       2011-01-05                 95
#
#    No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                          25                            49
# 1                          24                            56
# 2                          46                            62
# 3                          41                           102
# 4                          41                            54
#
#    Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 0                  287700                     148200
# 1                  300000                      95600
# 2                  522800                     210900
# 3                  737400                     238000
# 4                  387300                     213600
#
#    Amount withdrawn Other Card    Weekday Festival Religion Working Day  \
# 0                       139500   Saturday                 C           H
# 1                       204400     Sunday                NH           H
# 2                       311900     Monday                NH           W
# 3                       499400    Tuesday                NH           W
# 4                       173700  Wednesday                NH           W
#
#   Holiday Sequence  is_festival  Day_of_Week
# 0              WHH            1            5
# 1              HHW            0            6
# 2              WWW            0            0
# 3              WWW            0            1
# 4              WWW            0            2

# %%
df.isna().sum()
# Out:
# ATM Name                        0
# Transaction Date                0
# No Of Withdrawals               0
# No Of XYZ Card Withdrawals      0
# No Of Other Card Withdrawals    0
# Total amount Withdrawn          0
# Amount withdrawn XYZ Card       0
# Amount withdrawn Other Card     0
# Weekday                         0
# Festival Religion               0
# Working Day                     0
# Holiday Sequence                0
# is_festival                     0
# Day_of_Week                     0
# dtype: int64

# %%
# Create the target column: next day's 'Total amount Withdrawn'
df["Next_Day_Withdrawn"] = df["Total amount Withdrawn"].shift(-1)
df.head()
# Out:
#              ATM Name Transaction Date  No Of Withdrawals  \
# 0  Christ College ATM       2011-01-01                 74
# 1  Christ College ATM       2011-01-02                 80
# 2  Christ College ATM       2011-01-03                108
# 3  Christ College ATM       2011-01-04                143
# 4  Christ College ATM       2011-01-05                 95
#
#    No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                          25                            49
# 1                          24                            56
# 2                          46                            62
# 3                          41                           102
# 4                          41                            54
#
#    Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 0                  287700                     148200
# 1                  300000                      95600
# 2                  522800                     210900
# 3                  737400                     238000
# 4                  387300                     213600
#
#    Amount withdrawn Other Card    Weekday Festival Religion Working Day  \
# 0                       139500   Saturday                 C           H
# 1                       204400     Sunday                NH           H
# 2                       311900     Monday                NH           W
# 3                       499400    Tuesday                NH           W
# 4                       173700  Wednesday                NH           W
#
#   Holiday Sequence  is_festival  Day_of_Week  Next_Day_Withdrawn
# 0              WHH            1            5            300000.0
# 1              HHW            0            6            522800.0
# 2              WWW            0            0            737400.0
# 3              WWW            0            1            387300.0
# 4              WWW            0            2            430500.0

# %%
# Drop rows with missing target (i.e., last row)
df.dropna(subset=["Next_Day_Withdrawn"], inplace=True)

# %%
# Preview the cleaned and enhanced dataset
df[[
    "Transaction Date", "Total amount Withdrawn", "Next_Day_Withdrawn",
    "No Of Withdrawals", "is_festival", "Day_of_Week"
]].head()
# Out:
#   Transaction Date  Total amount Withdrawn  Next_Day_Withdrawn  \
# 0       2011-01-01                  287700            300000.0
# 1       2011-01-02                  300000            522800.0
# 2       2011-01-03                  522800            737400.0
# 3       2011-01-04                  737400            387300.0
# 4       2011-01-05                  387300            430500.0
#
#    No Of Withdrawals  is_festival  Day_of_Week
# 0                 74            1            5
# 1                 80            0            6
# 2                108            0            0
# 3                143            0            1
# 4                 95            0            2

# %%
df.isna().sum()
# Out:
# ATM Name                        0
# Transaction Date                0
# No Of Withdrawals               0
# No Of XYZ Card Withdrawals      0
# No Of Other Card Withdrawals    0
# Total amount Withdrawn          0
# Amount withdrawn XYZ Card       0
# Amount withdrawn Other Card     0
# Weekday                         0
# Festival Religion               0
# Working Day                     0
# Holiday Sequence                0
# is_festival                     0
# Day_of_Week                     0
# Next_Day_Withdrawn              0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
import numpy as np

# %%
# Step 1: Select features (X) and target (y)
features = [
    "No Of Withdrawals",
    "is_festival",
    "Day_of_Week"
]

# %%
X = df[features]
y = df["Next_Day_Withdrawn"]

# %%
# Step 2: Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
# Step 3: Train a Random Forest Regressor
model = RandomForestRegressor(random_state=42, n_estimators=100)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Step 4: Predict on test data and calculate MAE
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)

# %%
# Step 5: Predict for the next day (using last available row)
next_day_features = X.iloc[[-1]]

# %%
predicted_withdrawal = model.predict(next_day_features)[0]

# %%
# Step 6: Add a buffer (e.g., 10% or 15% if weekend/festival)
is_festival = int(next_day_features["is_festival"].values[0])
day_of_week = int(next_day_features["Day_of_Week"].values[0])

# %%
buffer_percent = 0.15 if is_festival or day_of_week in [5, 6] else 0.10
cash_to_load = predicted_withdrawal * (1 + buffer_percent)

# %%
mae, predicted_withdrawal, buffer_percent, cash_to_load
# Out:
# (264955.54822913493,
#  np.float64(644063.8285714285),
#  0.1,
#  np.float64(708470.2114285715))

# %%
# Compute the median safely
median_withdrawals = X["No Of Withdrawals"].median()

# Fill missing values safely
X.fillna({
    "No Of Withdrawals": median_withdrawals,
    "is_festival": 0
}, inplace=True)

# Forward fill for day of week
X["Day_of_Week"] = X["Day_of_Week"].ffill()

# Recreate target
y = df["Next_Day_Withdrawn"]

# Train-test split again
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Train the model again
model = RandomForestRegressor(random_state=42, n_estimators=100)
model.fit(X_train, y_train)

# Predict on test set and calculate MAE
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)

# Predict for the next day
next_day_features = X.iloc[[-1]]
predicted_withdrawal = model.predict(next_day_features)[0]

# Determine buffer
is_festival = int(next_day_features["is_festival"].values[0])
day_of_week = int(next_day_features["Day_of_Week"].values[0])
buffer_percent = 0.15 if is_festival or day_of_week in [5, 6] else 0.10


# Final amount to load
cash_to_load = predicted_withdrawal * (1 + buffer_percent)

# Determine the next day's date and name
last_date = df["Transaction Date"].max()
next_day = last_date + pd.Timedelta(days=1)
next_day_name = next_day.strftime("%A")

# %%
# Final output
predicted_withdrawal, buffer_percent, cash_to_load, next_day.strftime("%Y-%m-%d"), next_day_name
# Out:
# (np.float64(644063.8285714285),
#  0.1,
#  np.float64(708470.2114285715),
#  '2017-09-29',
#  'Friday')
